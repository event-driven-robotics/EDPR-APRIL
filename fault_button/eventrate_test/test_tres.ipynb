# %%
# %load_ext autoreload
# %autoreload 2
import os
import numpy as np

import src.utils as utils

# %%
scale = 1.0
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 9

# %%
sequence_name = "s1_v1"
path = os.path.join("/home/schiavazza/data/hpe/fault_button/osai/fault_button", sequence_name)

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s1_v1
# Examining info.log: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s1_v1/info.log
# Detection threshold: 97817.88549923323
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 9781.788549923323
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 978.1788549923325
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 97.81788549923324
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 100%|██████████| 20/20 [00:11<00:00,  1.75it/s]

# %%
scale = 1.0
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 9

sequence_name = "s1_v2"
path = os.path.join("/home/schiavazza/data/hpe/fault_button/osai/fault_button", sequence_name)

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s1_v2
# Examining info.log: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s1_v2/info.log
# Detection threshold: 97817.88549923323
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 9781.788549923323
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 978.1788549923325
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 97.81788549923324
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 100%|██████████| 20/20 [00:09<00:00,  2.00it/s]

# %%
scale = 1.0
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 9

sequence_name = "s2_v1"
path = os.path.join("/home/schiavazza/data/hpe/fault_button/osai/fault_button", sequence_name)

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s2_v1
# Examining info.log: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s2_v1/info.log
# Detection threshold: 97817.88549923323
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 9781.788549923323
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 978.1788549923325
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 97.81788549923324
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 100%|██████████| 20/20 [00:08<00:00,  2.28it/s]

# %%
scale = 1.0
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 9

sequence_name = "s2_v2"
path = os.path.join("/home/schiavazza/data/hpe/fault_button/osai/fault_button", sequence_name)

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s2_v2
# Examining info.log: /home/schiavazza/data/hpe/fault_button/osai/fault_button/s2_v2/info.log
# Detection threshold: 97817.88549923323
# Detection threshold: 9781.788549923323
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 978.1788549923325
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 97.81788549923324
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 100%|██████████| 20/20 [00:05<00:00,  3.44it/s]

# %%
scale = 1.0
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 9

sequence_name = "button4"
path = os.path.join("/home/schiavazza/data/hpe/fault_button/binary/long", sequence_name)

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/binary/long/button4
# Examining info.log: /home/schiavazza/data/hpe/fault_button/binary/long/button4/info.log
# Detection threshold: 221670.7776372958
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 22167.07776372958
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 2216.7077763729585
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 221.67077763729583
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 100%|██████████| 20/20 [00:12<00:00,  1.60it/s]

# %%
scale = 1.0
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 9

sequence_name = "button3"
path = os.path.join("/home/schiavazza/data/hpe/fault_button/binary/long", sequence_name)

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/binary/long/button3
# Examining info.log: /home/schiavazza/data/hpe/fault_button/binary/long/button3/info.log
# Detection threshold: 169716.6891285546
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 16971.668912855457
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 1697.1668912855462
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 169.7166891285546
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 100%|██████████| 20/20 [00:11<00:00,  1.71it/s]

# %%
scale = 1.0
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 9

sequence_name = "button2"
path = os.path.join("/home/schiavazza/data/hpe/fault_button/binary/long", sequence_name)

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/binary/long/button2
# Examining info.log: /home/schiavazza/data/hpe/fault_button/binary/long/button2/info.log
# Detection threshold: 102070.34531513238
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 10207.034531513238
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 1020.703453151324
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# Detection threshold: 102.07034531513239
# /usr/lib/python3/dist-packages/numpy/core/_methods.py:163: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = asanyarray(a)
# 100%|██████████| 20/20 [00:08<00:00,  2.48it/s]

# %%
scale = 0.2
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 3

sequence_name = "exp01"
path = f"/home/schiavazza/data/hpe/fault_button/APRIL/{sequence_name}/data"

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/APRIL/exp01/data
# 100%|██████████| 20781/20781 [00:06<00:00, 3164.57it/s]
# Examining info.log: /home/schiavazza/data/hpe/fault_button/APRIL/exp01/data/info.log
# [[  8.268543 353.       560.       386.       604.         0.      ]
#  [ 11.532415 344.       267.       384.       299.         0.      ]]
# Detection threshold: 3280.7652081438214
# Detection threshold: 328.0765208143821
# Detection threshold: 32.80765208143821
# Detection threshold: 3.2807652081438214
# 100%|██████████| 20/20 [00:00<00:00, 21.61it/s]

# %%
scale = 0.2
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 3

sequence_name = "exp03"
path = f"/home/schiavazza/data/hpe/fault_button/APRIL/{sequence_name}/data"

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/APRIL/exp03/data
# 100%|██████████| 38970/38970 [00:10<00:00, 3647.88it/s]
# Examining info.log: /home/schiavazza/data/hpe/fault_button/APRIL/exp03/data/info.log
# [[  7.169204 358.       588.       394.       627.         0.      ]
#  [ 11.97159  321.       330.       354.       357.         0.      ]]
# Detection threshold: 2548.4599605920407
# Detection threshold: 254.84599605920403
# Detection threshold: 25.484599605920405
# Detection threshold: 2.5484599605920404
# 100%|██████████| 20/20 [00:01<00:00, 14.27it/s]

# %%
scale = 0.2
dataset_tres_ls = [10**(-x) for x in np.linspace(1, 4, 4)]
dataset_tres_ls2 = [10**(-x) for x in np.linspace(1, 4, 20)]
base_thresh = 3

sequence_name = "exp03"
path = f"/home/schiavazza/data/hpe/fault_button/APRIL/{sequence_name}/data"

plotter = utils.Plotter(path)
plotter.plot_tres(base_thresh, dataset_tres_ls, scale, sequence_name)
plotter.test_tres(base_thresh, scale, dataset_tres_ls2)
# Out:
# importIitYarp trying path: /home/schiavazza/data/hpe/fault_button/APRIL/exp03/data
# 100%|██████████| 38970/38970 [00:10<00:00, 3660.85it/s]
# Examining info.log: /home/schiavazza/data/hpe/fault_button/APRIL/exp03/data/info.log
# [[  7.169204 358.       588.       394.       627.         0.      ]
#  [ 11.97159  321.       330.       354.       357.         0.      ]]
# Detection threshold: 2548.4599605920407
# Detection threshold: 254.84599605920403
# Detection threshold: 25.484599605920405
# Detection threshold: 2.5484599605920404
# 100%|██████████| 20/20 [00:01<00:00, 14.74it/s]
